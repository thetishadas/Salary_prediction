# %%
import pandas as pd

data = pd.read_csv('C:/Users/hp/Downloads/Salary prediction/employee_attrition_data.csv')
data.head()
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Job_Title              1000 non-null   object
#  5   Years_at_Company       1000 non-null   int64
#  6   Satisfaction_Level     1000 non-null   float64
#  7   Average_Monthly_Hours  1000 non-null   int64
#  8   Promotion_Last_5Years  1000 non-null   int64
#  9   Salary                 1000 non-null   int64
#  10  Attrition              1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
data.isna()
# Out:
#      Employee_ID    Age  Gender  Department  Job_Title  Years_at_Company  \
# 0          False  False   False       False      False             False
# 1          False  False   False       False      False             False
# 2          False  False   False       False      False             False
# 3          False  False   False       False      False             False
# 4          False  False   False       False      False             False
# ..           ...    ...     ...         ...        ...               ...
# 995        False  False   False       False      False             False
# 996        False  False   False       False      False             False
# 997        False  False   False       False      False             False
# 998        False  False   False       False      False             False
# 999        False  False   False       False      False             False
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0                 False                  False                  False   False
# 1                 False                  False                  False   False
# 2                 False                  False                  False   False
# 3                 False                  False                  False   False
# 4                 False                  False                  False   False
# ..                  ...                    ...                    ...     ...
# 995               False                  False                  False   False
# 996               False                  False                  False   False
# 997               False                  False                  False   False
# 998               False                  False                  False   False
# 999               False                  False                  False   False
#
#      Attrition
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 995      False
# 996      False
# 997      False
# 998      False
# 999      False
#
# [1000 rows x 11 columns]

# %%
data.isna().sum()
# Out:
# Employee_ID              0
# Age                      0
# Gender                   0
# Department               0
# Job_Title                0
# Years_at_Company         0
# Satisfaction_Level       0
# Average_Monthly_Hours    0
# Promotion_Last_5Years    0
# Salary                   0
# Attrition                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')

# %%
data.drop(columns= "Employee_ID",inplace=True)

# %%
data.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
data["Gender"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Gender Count of Employees")
plt.show()

# %%
data.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
data.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="line")
plt.title("Average Salary by Job Title")
plt.xlabel("Job Title")
plt.ylabel("Average Salary")
plt.show()

# %%
data.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
data.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
data.describe()
# Out:
#                Age  Years_at_Company  Satisfaction_Level  \
# count  1000.000000       1000.000000         1000.000000
# mean     42.205000          5.605000            0.505995
# std      10.016452          2.822223            0.289797
# min      25.000000          1.000000            0.001376
# 25%      33.000000          3.000000            0.258866
# 50%      43.000000          6.000000            0.505675
# 75%      51.000000          8.000000            0.761135
# max      59.000000         10.000000            0.999979
#
#        Average_Monthly_Hours  Promotion_Last_5Years        Salary    Attrition
# count            1000.000000            1000.000000   1000.000000  1000.000000
# mean              199.493000               0.486000  64624.980000     0.495000
# std                29.631908               0.500054  20262.984333     0.500225
# min               150.000000               0.000000  30099.000000     0.000000
# 25%               173.000000               0.000000  47613.500000     0.000000
# 50%               201.000000               0.000000  64525.000000     0.000000
# 75%               225.000000               1.000000  81921.000000     1.000000
# max               249.000000               1.000000  99991.000000     1.000000

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Department', 'Job_Title', 'Years_at_Company',
#        'Satisfaction_Level', 'Average_Monthly_Hours', 'Promotion_Last_5Years',
#        'Salary', 'Attrition'],
#       dtype='object')

# %%
data.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
X = data[["Years_at_Company","Satisfaction_Level","Average_Monthly_Hours"]]
y = data["Salary"]

# %%
# !pip install scikit-learn
# Out:
# ^C

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.86965991, -1.44535355, -0.13704082],
#        [ 0.16690443, -1.75096798,  1.21394692],
#        [-0.53585105,  0.35320807, -0.10326613],
#        ...,
#        [ 1.57241539, -1.13589445,  1.48414447],
#        [-0.53585105,  1.60933934,  0.2682555 ],
#        [ 1.22103765,  0.41477896, -0.84630938]])

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-1.08561605,  0.37253319,  0.57909593],
#        [-0.34331448, -1.02006586,  0.78634768],
#        [ 0.39898709,  1.82290627, -1.49342157],
#        [ 1.14128867,  0.72086148,  1.09722531],
#        [ 0.02783631,  0.37575826,  1.2699351 ],
#        [-1.82791762, -1.65427322, -1.76975724],
#        [-0.34331448, -1.53815814, -1.56250549],
#        [-1.82791762, -0.95443374,  0.4409281 ],
#        [ 1.51243945, -0.26681384, -1.42433765],
#        [-1.45676683, -1.05090562,  0.61363789],
#        [ 0.39898709,  1.25591663, -1.18254394],
#        [ 0.77013788, -0.5440794 ,  1.44264489],
#        [ 0.77013788, -0.65784883,  0.71726377],
#        [ 1.51243945, -0.17438993,  1.06268335],
#        [-0.71446526, -1.59390639, -0.18082715],
#        [ 0.39898709, -0.92066548,  1.51172881],
#        [-0.71446526,  1.69643892,  0.82088964],
#        [ 0.39898709, -0.42625249, -0.59533065],
#        [-0.34331448, -0.91599546, -1.80429919],
#        [-1.45676683, -0.01942155,  1.37356097],
#        [-0.34331448,  0.7749743 ,  1.23539314],
#        [-0.34331448,  0.18246521,  0.26821831],
#        [ 1.14128867,  0.1489479 , -0.76804044],
#        [-1.82791762,  1.67636459,  1.2699351 ],
#        [ 0.39898709,  1.49605035, -0.45716282],
#        [ 1.14128867,  1.13770886, -1.42433765],
#        [ 1.14128867, -1.22666394, -0.94075024],
#        [ 1.51243945, -1.14148957, -1.11346003],
#        [ 1.14128867,  0.98062151, -1.66613136],
#        [-0.34331448,  1.0837734 ,  1.23539314],
#        [ 1.51243945,  0.94940946, -1.90792507],
#        [ 1.14128867, -1.02120593,  0.47547006],
#        [ 1.14128867, -1.30667643,  0.99359943],
#        [ 0.77013788, -1.23408504,  0.47547006],
#        [-0.71446526, -0.6240775 , -1.32071178],
#        [ 0.02783631, -0.28319645,  1.20085118],
#        [-0.71446526,  1.632342  ,  0.13005047],
#        [-1.45676683,  0.23430681,  0.78634768],
#        [ 1.51243945, -0.2451749 , -0.21536911],
#        [-1.08561605,  1.10274591,  0.37184418],
#        [ 0.39898709, -0.89024697,  0.82088964],
#        [ 0.39898709, -1.35157292,  1.47718685],
#        [ 1.14128867, -0.91537397, -0.42262086],
#        [-1.82791762,  1.81757874,  0.99359943],
#        [ 0.02783631, -0.59641353, -1.70067332],
#        [-1.08561605,  0.34279172, -0.49170478],
#        [ 0.02783631, -1.59785051,  1.40810293],
#        [-1.45676683,  0.00956841,  0.95905747],
#        [-1.08561605,  0.78872823,  0.37184418],
#        [ 0.77013788, -0.44116194, -0.11174324],
#        [ 0.39898709, -1.43561009, -0.69895653],
#        [ 1.14128867,  1.33179687, -0.11174324],
#        [ 0.39898709, -0.90465247,  0.57909593],
#        [ 0.02783631,  1.8030722 ,  1.37356097],
#        [-0.34331448,  0.51011495, -0.04265932],
#        [-0.71446526, -1.44318972, -1.07891807],
#        [ 0.39898709, -0.03106152,  1.20085118],
#        [ 0.39898709,  0.12190923, -0.62987261],
#        [ 1.51243945,  1.18844498,  1.20085118],
#        [ 1.14128867,  0.98160801, -1.04437611],
#        [ 0.77013788,  0.04003914,  0.30276026],
#        [ 0.77013788,  1.07175447, -0.52624674],
#        [-1.82791762,  1.56295771,  1.51172881],
#        [ 0.77013788, -0.75286104,  0.51001201],
#        [-0.34331448, -1.11852166, -0.73349849],
#        [ 1.14128867,  1.22988996,  1.2699351 ],
#        [ 0.39898709, -1.59402346,  1.23539314],
#        [-1.08561605,  1.37167316, -0.73349849],
#        [-0.71446526,  1.44298444, -0.49170478],
#        [ 0.39898709, -1.09556649, -0.24991107],
#        [ 0.77013788,  0.1550084 , -0.45716282],
#        [-0.34331448,  0.71415257,  0.75180572],
#        [-0.71446526,  0.84372312, -0.52624674],
#        [ 1.14128867, -0.92569481, -1.49342157],
#        [ 0.77013788,  0.69039612,  0.95905747],
#        [ 1.51243945,  0.10799075, -0.87166632],
#        [ 0.02783631,  0.43430606,  0.78634768],
#        [ 1.51243945, -0.1563631 , -0.35353694],
#        [ 1.14128867, -1.03680044,  0.30276026],
#        [ 1.51243945, -1.41940522,  1.02814139],
#        [-0.34331448,  1.41437157, -0.35353694],
#        [-1.82791762,  1.11633012,  0.54455397],
#        [ 0.02783631,  0.65967546, -0.24991107],
#        [ 1.51243945,  0.35173469,  0.37184418],
#        [ 0.39898709,  0.53192379,  0.33730222],
#        [-1.45676683,  0.78409056, -1.42433765],
#        [ 0.77013788,  0.97681098,  0.95905747],
#        [ 0.77013788, -0.75057347, -0.42262086],
#        [-1.45676683, -1.56614612,  0.54455397],
#        [-0.34331448, -0.47927019, -1.56250549],
#        [ 1.51243945, -1.3883008 , -0.66441457],
#        [-1.45676683,  1.51109997, -1.00983415],
#        [ 1.14128867,  1.16641765,  1.51172881],
#        [-0.34331448,  1.13804537, -0.11174324],
#        [ 0.39898709,  1.72341392,  1.44264489],
#        [-0.71446526, -1.10524912,  1.2699351 ],
#        [-0.71446526,  0.61650516,  0.19913439],
#        [-1.08561605,  0.4968566 , -0.3880789 ],
#        [-1.82791762,  0.7021665 ,  0.09550851],
#        [-0.71446526,  1.14483856, -1.28616982],
#        [ 1.51243945,  0.02621586, -0.11174324],
#        [ 0.39898709,  0.73559535,  0.95905747],
#        [-0.71446526, -1.24206165,  1.30447706],
#        [ 1.51243945, -0.74040143, -0.45716282],
#        [ 0.02783631,  0.88930457, -1.73521528],
#        [-1.08561605, -0.40465657,  1.30447706],
#        [ 0.39898709, -0.4150376 , -0.56078869],
#        [-0.71446526,  0.98085176,  1.16630922],
#        [ 1.14128867, -0.52676247, -0.87166632],
#        [ 1.51243945, -1.64389375, -0.97529219],
#        [ 0.39898709, -0.7036928 ,  0.8554316 ],
#        [ 0.39898709,  0.81285931, -0.62987261],
#        [-1.08561605, -0.34191075,  1.16630922],
#        [-0.34331448,  0.19530191,  0.30276026],
#        [-0.71446526, -1.3095154 , -1.59704744],
#        [-1.08561605, -0.84541984,  1.13176727],
#        [ 0.77013788,  1.71687727, -1.28616982],
#        [-0.71446526,  0.60554719, -1.14800199],
#        [ 0.77013788, -0.2354487 , -0.59533065],
#        [-0.34331448, -1.6440537 ,  1.47718685],
#        [ 0.02783631, -0.59199465,  0.78634768],
#        [ 0.39898709,  1.31606917, -0.14628519],
#        [ 1.51243945, -1.33924331, -1.49342157],
#        [-1.08561605, -0.32366609,  0.57909593],
#        [-1.45676683, -0.53396705, -0.97529219],
#        [ 0.02783631, -0.19929124, -0.45716282],
#        [-1.08561605, -0.34426385,  1.02814139],
#        [ 0.39898709, -0.06259642,  0.30276026],
#        [ 1.14128867,  0.65594337,  1.47718685],
#        [-1.45676683, -0.08913712, -0.14628519],
#        [-1.08561605, -0.30040483, -0.31899499],
#        [-0.34331448,  0.01668009, -0.18082715],
#        [ 0.02783631, -1.04400537,  0.19913439],
#        [-0.71446526,  0.3167095 ,  1.40810293]])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

def results(predictions):
  print("Mean absolute error on model is {}",format(mean_absolute_error(y_test,predictions)))
  print("Root maen squared error on model is {}",format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictionlr = lr.predict(X_test)

# %%
results(predictionlr)
# Out:
# Mean absolute error on model is {} 17581.654428973823
# Root maen squared error on model is {} 20243.734293954476

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
svrmodel = SVR()

# %%
param_gridsvr = {
    'C': [0.1, 1, 10],
    'epsilon': [0.1, 0.2, 0.5],
    'kernel': ['linear', 'poly', 'rbf'],  # Ensure valid kernel types
    'degree': [2, 3, 4],  # Only applicable if 'poly' kernel is used
}

# %%
gridsvr = GridSearchCV(svrmodel, param_gridsvr)

# %%
gridsvr.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 10, 'degree': 2, 'epsilon': 0.1, 'kernel': 'linear'}

# %%
predictionssvr = gridsvr.predict(X_test)

# %%
results(predictionssvr)
# Out:
# Mean absolute error on model is {} 17724.203088248818
# Root maen squared error on model is {} 20297.90509729604

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel = RandomForestRegressor()

# %%
param_gridrfr = {
    "n_estimators": [2, 3, 4, 5, 6],  # Use a list instead of a set
    "max_depth": [5, 10, 15]
}

# %%
gridrfr = GridSearchCV(estimator=rfmodel, param_grid=param_gridrfr, cv=5)

# %%
gridrfr.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 5}

# %%
predictionofrfr = gridrfr.predict(X_test)

# %%
results(predictionofrfr)
# Out:
# Mean absolute error on model is {} 17616.48885308515
# Root maen squared error on model is {} 20274.70258217988

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr, "model.pkl")
# Out:
# ['model.pkl']

# %%
X.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')
